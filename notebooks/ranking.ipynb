# %%
import pandas as pd
merchants = pd.read_parquet('../data/curated/merchant_info.parquet')
merchants.reset_index(inplace=True)
merchants.head(20)
# Out:
#     index  merchant_abn                                  name  \
# 0       0   10023283211                         Felis Limited
# 1       1   10142254217              Arcu Ac Orci Corporation
# 2       2   10165489824                      Nunc Sed Company
# 3       3   10187291046  Ultricies Dignissim Lacus Foundation
# 4       4   10192359162                   Enim Condimentum PC
# 5       5   10206519221                         Fusce Company
# 6       6   10255988167             Aliquam Enim Incorporated
# 7       7   10264435225                      Ipsum Primis Ltd
# 8       8   10279061213              Pede Ultrices Industries
# 9       9   10323485998                             Nunc Inc.
# 10     10   10342410215             Facilisis Facilisis Corp.
# 11     11   10346855916                        Odio Institute
# 12     12   10364012396                      Rutrum Justo Ltd
# 13     13   10385011947                     Tellus Foundation
# ...
